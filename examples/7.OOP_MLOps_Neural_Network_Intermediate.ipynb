# %% [markdown]
# # OOP MLOps Neural Network Intermediate - Iris Flower Classification
#
# <img src="images\Iris-Dataset-Classification-1024x367.png"/>

# %% [markdown]
# **Project Description:**
#
# The Iris Flower Classification project focuses on developing a machine learning model to classify iris flowers into their respective species based on specific measurements. Iris flowers are classified into three species: setosa, versicolor, and virginica, each of which exhibits distinct characteristics in terms of measurements.
#
# **Key Details:**
#
# - Iris flowers have three species: setosa, versicolor, and virginica.
# - These species can be distinguished based on measurements such as sepal length, sepal width, petal length, and petal width.
# - The project involves training a machine learning model on a dataset that contains iris flower measurements associated with their respective species.
# - The trained model will classify iris flowers into one of the three species based on their measurements.
#
# **Project Purpose**
#
# This project's significance lies in its potential to streamline and automate the classification of iris species, which can have broader applications in botany, horticulture, and environmental monitoring.

# %% [markdown]
# #### 1. Import Dependencies

# %%
# Import Libraries
# Importing Numpy & Pandas for data processing & data wrangling
import numpy as np
import pandas as pd

# Importing  tools for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Library used for data preprocessing
from sklearn.preprocessing import LabelEncoder

# Import model selection libraries
from sklearn.model_selection import train_test_split

# Library used for ML Model implementation
import tensorflow as tf
from tensorflow.keras.layers import Dense

# Library used for ignore warnings
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# 2025-04-28 09:23:15.914251: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-28 09:23:16.091895: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-28 09:23:16.162605: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745832196.257759    4525 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745832196.291814    4525 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745832196.542352    4525 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745832196.542403    4525 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745832196.542406    4525 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745832196.542408    4525 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-28 09:23:16.560047: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### 2. Dataset Loading

# %%
# Load Dataset
df = pd.read_csv("data/Iris.csv")

# %% [markdown]
# #### 3. Preview Dataset

# %%
# Dataset First Look
# View top 5 rows of the dataset
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Dataset Rows & Columns count
# Checking number of rows and columns of the dataset using shape
print("Number of rows are: ",df.shape[0])
print("Number of columns are: ",df.shape[1])
# Out:
# Number of rows are:  150
# Number of columns are:  6

# %%
# Dataset Info
# Checking information about the dataset using info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# Dataset Describe (all columns included)
df.describe(include= 'all').round(2)
# Out:
#             Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.00         150.00        150.00         150.00        150.00
# unique     NaN            NaN           NaN            NaN           NaN
# top        NaN            NaN           NaN            NaN           NaN
# freq       NaN            NaN           NaN            NaN           NaN
# mean     75.50           5.84          3.05           3.76          1.20
# std      43.45           0.83          0.43           1.76          0.76
# min       1.00           4.30          2.00           1.00          0.10
# 25%      38.25           5.10          2.80           1.60          0.30
# 50%      75.50           5.80          3.00           4.35          1.30
# 75%     112.75           6.40          3.30           5.10          1.80
# max     150.00           7.90          4.40           6.90          2.50
#
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %% [markdown]
# #### 4. Data Wrangling

# %%
# We don't need the 1st column so let's drop it
data=df.iloc[:,1:]

# %%
# New updated dataset
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #### 5. Data Vizualization

# %% [markdown]
# ###### **5.1 Histogram visualization for distribution of numerical variables**

# %%
# Chart 1 - Histogram visualization code for distribution of numerical variables
# Create a figure with subplots
plt.figure(figsize=(8, 6))
plt.suptitle('Distribution of Iris Flower Measurements', fontsize=14)

# Create a 2x2 grid of subplots
plt.subplot(2, 2, 1)  # Subplot 1 (Top-Left)
plt.hist(data['SepalLengthCm'])
plt.title('Sepal Length Distribution')

plt.subplot(2, 2, 2)  # Subplot 2 (Top-Right)
plt.hist(data['SepalWidthCm'])
plt.title('Sepal Width Distribution')

plt.subplot(2, 2, 3)  # Subplot 3 (Bottom-Left)
plt.hist(data['PetalLengthCm'])
plt.title('Petal Length Distribution')

plt.subplot(2, 2, 4)  # Subplot 4 (Bottom-Right)
plt.hist(data['PetalWidthCm'])
plt.title('Petal Width Distribution')

# Display the subplots
plt.tight_layout()  # Helps in adjusting the layout
plt.show()

# %%
# Define colors for each species and the corresponding species labels.
colors = ['red', 'yellow', 'green']
species = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %% [markdown]
# ###### **5.2 Scatter plot visualizations for Sepal Length vs Sepal Width**

# %%
# Chart 2 - Scatter plot visualizations for Sepal Length vs Sepal Width.
# Create a scatter plot for Sepal Length vs Sepal Width for each species.
for i in range(3):
    # Select data for the current species.
    x = data[data['Species'] == species[i]]

    # Create a scatter plot with the specified color and label for the current species.
    plt.scatter(x['SepalLengthCm'], x['SepalWidthCm'], c=colors[i], label=species[i])

# Add labels to the x and y axes.
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')

# Add a legend to identify species based on colors.
plt.legend()

# Display the scatter plot.
plt.show()

# %% [markdown]
# ###### **5.3 Scatter plot visualization for Petal Length vs Petal Width**

# %%
# Chart 3 - Scatter plot visualization code for Petal Length vs Petal Width.
# Create a scatter plot for Petal Length vs Petal Width for each species.
for i in range(3):
    # Select data for the current species.
    x = data[data['Species'] == species[i]]

    # Create a scatter plot with the specified color and label for the current species.
    plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'], c=colors[i], label=species[i])

# Add labels to the x and y axes.
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')

# Add a legend to identify species based on colors.
plt.legend()

# Display the scatter plot.
plt.show()

# %% [markdown]
# ###### **5.4 Scatter plot visualization for Sepal Length vs Petal Length**

# %%
# Chart 4 - Scatter plot visualization code for Sepal Length vs Petal Length.
# Create a scatter plot for Sepal Length vs Petal Length for each species.
for i in range(3):
    # Select data for the current species.
    x = data[data['Species'] == species[i]]

    # Create a scatter plot with the specified color and label for the current species.
    plt.scatter(x['SepalLengthCm'], x['PetalLengthCm'], c=colors[i], label=species[i])

# Add labels to the x and y axes.
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')

# Add a legend to identify species based on colors.
plt.legend()

# Display the scatter plot.
plt.show()

# %% [markdown]
# ###### **5.5 Scatter plot visualization code for Sepal Width vs Petal Width**

# %%
# Chart 5 - Scatter plot visualization code for Sepal Width vs Petal Width.
# Create a scatter plot for Sepal Width vs Petal Width for each species.
for i in range(3):
    # Select data for the current species.
    x = data[data['Species'] == species[i]]

    # Create a scatter plot with the specified color and label for the current species.
    plt.scatter(x['SepalWidthCm'], x['PetalWidthCm'], c=colors[i], label=species[i])

# Add labels to the x and y axes.
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')

# Add a legend to identify species based on colors.
plt.legend()

# Display the scatter plot.
plt.show()

# %% [markdown]
# ###### **5.6 Correlation Heatmap Visualization**

# %%
# Chart 6 - Correlation Heatmap Visualization Code
corr_matrix = data.corr(numeric_only=True)

# Plot Heatmap
plt.figure(figsize=(8, 4))
sns.heatmap(corr_matrix, annot=True, cmap='Reds_r')

# Setting Labels
plt.title('Correlation Matrix heatmap')

# Display Chart
plt.show()

# %% [markdown]
# #### 6. Feature Engineering

# %% [markdown]
# ###### **6.1 Categorical Encoding**

# %%
# Encode the categorical columns
# Create a LabelEncoder object
le = LabelEncoder()

# Encode the 'Species' column to convert the species names to numerical labels
data['Species'] = le.fit_transform(data['Species'])

# Check the unique values in the 'Species' column after encoding
unique_species = data['Species'].unique()

# Display the unique encoded values
print("Encoded Species Values:")
print(unique_species) # 'Iris-setosa' == 0, 'Iris-versicolor' == 1, 'Iris-virginica' == 2
# Out:
# Encoded Species Values:
# [0 1 2]

# %% [markdown]
# ###### **6.2 Data Scaling**

# %%
# Defining the X and y
x=data.drop(columns=['Species'], axis=1)
y=data['Species']

# %% [markdown]
# ###### **6.3 Training/Testing Data Split**

# %%
# Splitting the data to train and test
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.3)

# %%
# Checking the train distribution of dependent variable
y_train.value_counts()
# Out:
# Species
# 0    38
# 2    35
# 1    32
# Name: count, dtype: int64

# %% [markdown]
# #### 7. Neural Network Model Implementation

# %% [markdown]
# ###### **7.1 Build and compile the Neural Network Model**

# %%
model = tf.keras.Sequential([
    Dense(64, activation='relu', input_shape=(x_train.shape[1],)),  # Input layer with 64 neurons
    Dense(32, activation='relu'),  # Hidden layer with 32 neurons
    Dense(3, activation='softmax')  # Output layer with 3 neurons (one for each class)
])

model.compile(optimizer='adam',  # Adam optimizer
              loss='sparse_categorical_crossentropy',  # Loss function for multi-class classification
              metrics=['accuracy'])  # Metric to evaluate performance
# Out:
# 2025-04-28 09:23:21.059245: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# ###### **7.2 Train the model**

# %%
model.fit(x_train, y_train, epochs=50, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.2708 - loss: 1.5152 - val_accuracy: 0.3333 - val_loss: 1.1000
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3682 - loss: 1.1351 - val_accuracy: 0.3333 - val_loss: 1.0138
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3798 - loss: 1.0029 - val_accuracy: 0.5714 - val_loss: 0.9517
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6304 - loss: 0.9226 - val_accuracy: 0.6667 - val_loss: 0.9023
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6672 - loss: 0.8535 - val_accuracy: 0.7143 - val_loss: 0.8472
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7936 - loss: 0.7660 - val_accuracy: 0.7143 - val_loss: 0.7990
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6987 - loss: 0.7225 - val_accuracy: 0.6667 - val_loss: 0.7592
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7233 - loss: 0.6678 - val_accuracy: 0.7619 - val_loss: 0.7104
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7267 - loss: 0.6378 - val_accuracy: 0.7619 - val_loss: 0.6717
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7730 - loss: 0.5855 - val_accuracy: 0.7619 - val_loss: 0.6475
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7693 - loss: 0.5666 - val_accuracy: 0.7619 - val_loss: 0.6180
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7745 - loss: 0.5201 - val_accuracy: 0.8571 - val_loss: 0.5877
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8388 - loss: 0.5296 - val_accuracy: 0.8095 - val_loss: 0.5554
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9577 - loss: 0.4746 - val_accuracy: 0.8571 - val_loss: 0.5460
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8020 - loss: 0.4597 - val_accuracy: 0.7619 - val_loss: 0.5420
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7700 - loss: 0.4570 - val_accuracy: 0.8095 - val_loss: 0.5082
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9190 - loss: 0.4063 - val_accuracy: 0.8095 - val_loss: 0.4863
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9487 - loss: 0.4147 - val_accuracy: 0.8571 - val_loss: 0.4722
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9227 - loss: 0.3916 - val_accuracy: 0.8095 - val_loss: 0.4605
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9005 - loss: 0.3701 - val_accuracy: 0.8571 - val_loss: 0.4723
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8514 - loss: 0.3661 - val_accuracy: 0.8571 - val_loss: 0.4451
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9280 - loss: 0.3744 - val_accuracy: 0.8095 - val_loss: 0.4322
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9258 - loss: 0.3255 - val_accuracy: 0.8571 - val_loss: 0.4285
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9160 - loss: 0.3295 - val_accuracy: 0.8095 - val_loss: 0.4073
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9766 - loss: 0.3158 - val_accuracy: 0.8571 - val_loss: 0.3985
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9770 - loss: 0.2836 - val_accuracy: 0.8571 - val_loss: 0.4007
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9896 - loss: 0.2967 - val_accuracy: 0.8571 - val_loss: 0.3790
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9851 - loss: 0.2592 - val_accuracy: 0.8571 - val_loss: 0.3702
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9673 - loss: 0.2628 - val_accuracy: 0.8571 - val_loss: 0.3623
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9874 - loss: 0.2664 - val_accuracy: 0.8571 - val_loss: 0.3631
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9570 - loss: 0.2359 - val_accuracy: 0.8571 - val_loss: 0.3482
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9606 - loss: 0.2516 - val_accuracy: 0.8571 - val_loss: 0.3434
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9584 - loss: 0.2377 - val_accuracy: 0.8571 - val_loss: 0.3313
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9844 - loss: 0.2138 - val_accuracy: 0.8571 - val_loss: 0.3379
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9510 - loss: 0.2273 - val_accuracy: 0.8571 - val_loss: 0.3213
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9896 - loss: 0.1974 - val_accuracy: 0.8571 - val_loss: 0.3133
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9896 - loss: 0.2055 - val_accuracy: 0.8571 - val_loss: 0.3070
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9632 - loss: 0.1954 - val_accuracy: 0.9048 - val_loss: 0.3175
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9851 - loss: 0.1949 - val_accuracy: 0.8571 - val_loss: 0.3032
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1905 - val_accuracy: 0.9048 - val_loss: 0.3087
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9662 - loss: 0.1754 - val_accuracy: 0.8571 - val_loss: 0.2998
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9710 - loss: 0.1681 - val_accuracy: 0.9048 - val_loss: 0.3141
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9554 - loss: 0.1959 - val_accuracy: 0.8571 - val_loss: 0.2838
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9926 - loss: 0.1658 - val_accuracy: 0.8571 - val_loss: 0.2895
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9435 - loss: 0.1622 - val_accuracy: 0.8571 - val_loss: 0.2804
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9896 - loss: 0.1288 - val_accuracy: 0.8571 - val_loss: 0.2722
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9822 - loss: 0.1496 - val_accuracy: 0.8571 - val_loss: 0.2757
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.1317 - val_accuracy: 0.8571 - val_loss: 0.2761
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9696 - loss: 0.1338 - val_accuracy: 0.9048 - val_loss: 0.2823
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9301 - loss: 0.1468 - val_accuracy: 0.8571 - val_loss: 0.2625

# %% [markdown]
# ###### **7.3 Evaluate the Model**

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9852 - loss: 0.1545
# Test Accuracy: 0.98

# %% [markdown]
# ###### **7.4 Make Predictions**

# %%
predictions = model.predict(x_test)
predicted_classes = predictions.argmax(axis=1)
print(predicted_classes)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [1 1 1 2 2 0 0 2 0 1 0 2 1 1 0 2 1 0 0 1 2 1 1 2 1 1 0 1 1 2 2 0 1 2 0 1 0
#  0 2 2 1 2 1 2 1]
